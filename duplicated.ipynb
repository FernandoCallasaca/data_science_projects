# %% [markdown]
# <a href="https://colab.research.google.com/github/FernandoCallasaca/data_science_projects/blob/main/duplicated.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Preparamos nuestro lugar de trabajo

# %% [markdown]
# ## Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd '/content/drive/My Drive/Data Science/Platzi/10. Curso de Manipulación y Análisis de datos con Pandas y Python/db/'
# !ls
# Out:
# /content/drive/My Drive/Data Science/Platzi/10. Curso de Manipulación y Análisis de datos con Pandas y Python/db
# london_merged.csv  Meteorite_Landings.csv  notas.csv  population-worldbank

# %%
path_file = lambda name_file: '/content/drive/My Drive/Data Science/Platzi/10. Curso de Manipulación y Análisis de datos con Pandas y Python/db/{}'.format(name_file)

# %%
path_file_read = path_file('notas.csv')
path_file_read
# Out:
# '/content/drive/My Drive/Data Science/Platzi/10. Curso de Manipulación y Análisis de datos con Pandas y Python/db/notas.csv'

# %% [markdown]
# ## Librerías

# %%
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
# %matplotlib inline
pd.__version__
# Out:
# '1.1.5'

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %%
np.set_printoptions(precision=2)

# %% [markdown]
# # Empezamos a trabajar

# %%
df = pd.DataFrame(
    {
        'a': ['w']*4 + ['x']*3 + ['y']*2 + ['z'] + ['v'],
        'b': [1,1,1,1,2,2,2,3,3,4,5]
    }
)
df
# Out:
#     a  b
# 0   w  1
# 1   w  1
# 2   w  1
# 3   w  1
# 4   x  2
# 5   x  2
# 6   x  2
# 7   y  3
# 8   y  3
# 9   z  4
# 10  v  5

# %%
df.duplicated().to_frame()
# Out:
#         0
# 0   False
# 1    True
# 2    True
# 3    True
# 4   False
# 5    True
# 6    True
# 7   False
# 8    True
# 9   False
# 10  False

# %%
df.duplicated(keep='first').to_frame()
# Out:
#         0
# 0   False
# 1    True
# 2    True
# 3    True
# 4   False
# 5    True
# 6    True
# 7   False
# 8    True
# 9   False
# 10  False

# %%
df.duplicated(keep='last').to_frame()
# Out:
#         0
# 0    True
# 1    True
# 2    True
# 3   False
# 4    True
# 5    True
# 6   False
# 7    True
# 8   False
# 9   False
# 10  False

# %%
# para seleccionar las filas que no duplicadas
df[~df.duplicated()]
# Out:
#     a  b
# 0   w  1
# 4   x  2
# 7   y  3
# 9   z  4
# 10  v  5

# %%
# si quiero saber cuales son los registros duplicados
df.duplicated(keep = False)
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9     False
# 10    False
# dtype: bool

# %%
# solo traer las filas que aparecen una sola vez
df[~df.duplicated(keep=False)]
# Out:
#     a  b
# 9   z  4
# 10  v  5

# %%
df
# Out:
#     a  b
# 0   w  1
# 1   w  1
# 2   w  1
# 3   w  1
# 4   x  2
# 5   x  2
# 6   x  2
# 7   y  3
# 8   y  3
# 9   z  4
# 10  v  5

# %%
df.drop_duplicates()
# Out:
#     a  b
# 0   w  1
# 4   x  2
# 7   y  3
# 9   z  4
# 10  v  5

# %%
# eliminaremos los duplicados basándonos en la columna a
df.drop_duplicates(['a'], keep = 'last')
# Out:
#     a  b
# 3   w  1
# 6   x  2
# 8   y  3
# 9   z  4
# 10  v  5
